# %%
import torch
import numpy as np
import pandas as pd
import cv2
import shapely

print("All packages loaded successfully")
print("Torch version:", torch.__version__)
# Out:
# All packages loaded successfully
# Torch version: 2.8.0

# %%
import sys
# !{sys.executable} model/OOD_classification_baseline_unweighted.py
# Out:
# Loading OOD data...
#
# Using environment column for per environment analysis: disaster
#
# Split sizes:
# split
# OOD_train    166544
# OOD_hold      53403
# OOD_test      46833
# Name: count, dtype: int64
#
# Train label distribution:
# damage_label
# no-damage       120576
# major-damage     17327
# minor-damage     17063
# destroyed        11578
# Name: count, dtype: int64
#
# OOD validation label distribution:
# damage_label
# no-damage       37859
# destroyed        6089
# major-damage     2260
# minor-damage      625
# Name: count, dtype: int64
#
# OOD hold label distribution:
# damage_label
# no-damage       38388
# minor-damage     8428
# destroyed        3558
# major-damage     3029
# Name: count, dtype: int64
#
# Train environments:
# ['hurricane-harvey', 'hurricane-matthew', 'mexico-earthquake', 'palu-tsunami']
#
# OOD validation environments:
# ['guatemala-volcano', 'hurricane-florence', 'midwest-flooding', 'santa-rosa-wildfire']
#
# OOD hold environments:
# ['hurricane-michael', 'socal-fire']
#
# Image overlap check:
# OOD_train intersection OOD_val: 0
# OOD_train intersection OOD_hold: 0
# OOD_val intersection OOD_hold: 0
#
# Location overlap check:
# OOD_train intersection OOD_val: 0
# OOD_train intersection OOD_hold: 0
# OOD_val intersection OOD_hold: 0
#
# PASS: no image or location overlap.
#
# Using device: mps
#
# ================================================================================
# Starting OOD baseline seed 42
# ================================================================================
#
# Using unweighted cross entropy.
#
# Starting OOD training...
# Seed 42 | OOD Epoch 1/8: 100%|█| 5205/5205 [36:32<00:00,  2.37it/s, loss=0.4311]
# Seed 42 | Epoch 01 | Train Loss: 0.4772 | OOD Val Loss: 0.8265 | OOD Val Macro F1: 0.4170 | Time: 39.92 min
# Seed 42 | OOD Epoch 2/8: 100%|█| 5205/5205 [40:45<00:00,  2.13it/s, loss=0.4191]
# Seed 42 | Epoch 02 | Train Loss: 0.3815 | OOD Val Loss: 0.7997 | OOD Val Macro F1: 0.4535 | Time: 44.22 min
# Seed 42 | OOD Epoch 3/8: 100%|█| 5205/5205 [1:51:01<00:00,  1.28s/it, loss=0.458
# Seed 42 | Epoch 03 | Train Loss: 0.3349 | OOD Val Loss: 0.6432 | OOD Val Macro F1: 0.4733 | Time: 113.88 min
# Seed 42 | OOD Epoch 4/8: 100%|█| 5205/5205 [37:33<00:00,  2.31it/s, loss=0.4214]
# Seed 42 | Epoch 04 | Train Loss: 0.2833 | OOD Val Loss: 0.8180 | OOD Val Macro F1: 0.4351 | Time: 39.97 min
# Seed 42 | OOD Epoch 5/8: 100%|█| 5205/5205 [38:13<00:00,  2.27it/s, loss=0.1131]
# Seed 42 | Epoch 05 | Train Loss: 0.2179 | OOD Val Loss: 1.1261 | OOD Val Macro F1: 0.4131 | Time: 41.30 min
# Seed 42 | OOD Epoch 6/8: 100%|█| 5205/5205 [35:53<00:00,  2.42it/s, loss=0.1840]
# Seed 42 | Epoch 06 | Train Loss: 0.1559 | OOD Val Loss: 1.3140 | OOD Val Macro F1: 0.3868 | Time: 38.47 min
# Seed 42 | OOD Epoch 7/8: 100%|█| 5205/5205 [39:32<00:00,  2.19it/s, loss=0.4806]
# Seed 42 | Epoch 07 | Train Loss: 0.1134 | OOD Val Loss: 1.0929 | OOD Val Macro F1: 0.4293 | Time: 42.86 min
# Seed 42 | OOD Epoch 8/8: 100%|█| 5205/5205 [36:38<00:00,  2.37it/s, loss=0.1068]
# Seed 42 | Epoch 08 | Train Loss: 0.0898 | OOD Val Loss: 1.3999 | OOD Val Macro F1: 0.3958 | Time: 40.00 min
#
# ================================================================================
# Starting OOD baseline seed 123
# ================================================================================
#
# Using unweighted cross entropy.
#
# Starting OOD training...
# Seed 123 | OOD Epoch 1/8: 100%|█| 5205/5205 [40:11<00:00,  2.16it/s, loss=0.1971
# Seed 123 | Epoch 01 | Train Loss: 0.4744 | OOD Val Loss: 1.1085 | OOD Val Macro F1: 0.3192 | Time: 43.47 min
# Seed 123 | OOD Epoch 2/8: 100%|█| 5205/5205 [39:35<00:00,  2.19it/s, loss=0.5417
# Seed 123 | Epoch 02 | Train Loss: 0.3808 | OOD Val Loss: 1.0485 | OOD Val Macro F1: 0.3565 | Time: 42.69 min
# Seed 123 | OOD Epoch 3/8: 100%|█| 5205/5205 [35:17<00:00,  2.46it/s, loss=0.2427
# Seed 123 | Epoch 03 | Train Loss: 0.3332 | OOD Val Loss: 0.8825 | OOD Val Macro F1: 0.4147 | Time: 37.83 min
# Seed 123 | OOD Epoch 4/8: 100%|█| 5205/5205 [39:48<00:00,  2.18it/s, loss=0.2796
# Seed 123 | Epoch 04 | Train Loss: 0.2811 | OOD Val Loss: 0.9352 | OOD Val Macro F1: 0.3993 | Time: 43.05 min
# Seed 123 | OOD Epoch 5/8: 100%|█| 5205/5205 [1:07:20<00:00,  1.29it/s, loss=0.25
# Seed 123 | Epoch 05 | Train Loss: 0.2177 | OOD Val Loss: 1.1245 | OOD Val Macro F1: 0.3875 | Time: 70.03 min
# Seed 123 | OOD Epoch 6/8: 100%|█| 5205/5205 [30:50<00:00,  2.81it/s, loss=0.4999
# Seed 123 | Epoch 06 | Train Loss: 0.1581 | OOD Val Loss: 1.0379 | OOD Val Macro F1: 0.4252 | Time: 33.11 min
# Seed 123 | OOD Epoch 7/8: 100%|█| 5205/5205 [27:24<00:00,  3.16it/s, loss=0.2526
# Seed 123 | Epoch 07 | Train Loss: 0.1141 | OOD Val Loss: 1.0842 | OOD Val Macro F1: 0.4038 | Time: 29.64 min
# Seed 123 | OOD Epoch 8/8: 100%|█| 5205/5205 [27:10<00:00,  3.19it/s, loss=0.0053
# Seed 123 | Epoch 08 | Train Loss: 0.0890 | OOD Val Loss: 1.3123 | OOD Val Macro F1: 0.4049 | Time: 29.37 min
#
# ================================================================================
# Starting OOD baseline seed 999
# ================================================================================
#
# Using unweighted cross entropy.
#
# Starting OOD training...
# Seed 999 | OOD Epoch 1/8: 100%|█| 5205/5205 [26:50<00:00,  3.23it/s, loss=0.4518
# Seed 999 | Epoch 01 | Train Loss: 0.4741 | OOD Val Loss: 1.0120 | OOD Val Macro F1: 0.3810 | Time: 29.08 min
# Seed 999 | OOD Epoch 2/8: 100%|█| 5205/5205 [27:04<00:00,  3.20it/s, loss=0.3592
# Seed 999 | Epoch 02 | Train Loss: 0.3784 | OOD Val Loss: 0.9230 | OOD Val Macro F1: 0.4232 | Time: 29.26 min
# Seed 999 | OOD Epoch 3/8: 100%|█| 5205/5205 [26:44<00:00,  3.24it/s, loss=0.2900
# Seed 999 | Epoch 03 | Train Loss: 0.3289 | OOD Val Loss: 0.8935 | OOD Val Macro F1: 0.4178 | Time: 28.93 min
# Seed 999 | OOD Epoch 4/8: 100%|█| 5205/5205 [26:40<00:00,  3.25it/s, loss=0.6558
# Seed 999 | Epoch 04 | Train Loss: 0.2755 | OOD Val Loss: 0.9482 | OOD Val Macro F1: 0.4100 | Time: 28.84 min
# Seed 999 | OOD Epoch 5/8: 100%|█| 5205/5205 [26:38<00:00,  3.26it/s, loss=0.2461
# Seed 999 | Epoch 05 | Train Loss: 0.2099 | OOD Val Loss: 0.9005 | OOD Val Macro F1: 0.4339 | Time: 28.80 min
# Seed 999 | OOD Epoch 6/8: 100%|█| 5205/5205 [26:38<00:00,  3.26it/s, loss=0.3770
# Seed 999 | Epoch 06 | Train Loss: 0.1505 | OOD Val Loss: 1.1582 | OOD Val Macro F1: 0.4177 | Time: 28.79 min
# Seed 999 | OOD Epoch 7/8: 100%|█| 5205/5205 [26:30<00:00,  3.27it/s, loss=0.1421
# Seed 999 | Epoch 07 | Train Loss: 0.1099 | OOD Val Loss: 1.2929 | OOD Val Macro F1: 0.3630 | Time: 28.64 min
# Seed 999 | OOD Epoch 8/8: 100%|█| 5205/5205 [26:28<00:00,  3.28it/s, loss=0.1511
# Seed 999 | Epoch 08 | Train Loss: 0.0852 | OOD Val Loss: 1.0926 | OOD Val Macro F1: 0.4290 | Time: 28.61 min
#
# ================================================================================
# Starting OOD baseline seed 2024
# ================================================================================
#
# Using unweighted cross entropy.
#
# Starting OOD training...
# Seed 2024 | OOD Epoch 1/8: 100%|█| 5205/5205 [26:18<00:00,  3.30it/s, loss=0.394
# Seed 2024 | Epoch 01 | Train Loss: 0.4763 | OOD Val Loss: 0.9692 | OOD Val Macro F1: 0.4308 | Time: 28.51 min
# Seed 2024 | OOD Epoch 2/8: 100%|█| 5205/5205 [26:18<00:00,  3.30it/s, loss=0.328
# Seed 2024 | Epoch 02 | Train Loss: 0.3819 | OOD Val Loss: 0.9839 | OOD Val Macro F1: 0.4296 | Time: 28.42 min
# Seed 2024 | OOD Epoch 3/8: 100%|█| 5205/5205 [26:14<00:00,  3.31it/s, loss=0.446
# Seed 2024 | Epoch 03 | Train Loss: 0.3345 | OOD Val Loss: 0.9734 | OOD Val Macro F1: 0.4295 | Time: 28.40 min
# Seed 2024 | OOD Epoch 4/8: 100%|█| 5205/5205 [26:12<00:00,  3.31it/s, loss=0.649
# Seed 2024 | Epoch 04 | Train Loss: 0.2803 | OOD Val Loss: 0.8811 | OOD Val Macro F1: 0.4271 | Time: 28.31 min
# Seed 2024 | OOD Epoch 5/8: 100%|█| 5205/5205 [26:08<00:00,  3.32it/s, loss=0.353
# Seed 2024 | Epoch 05 | Train Loss: 0.2150 | OOD Val Loss: 0.9667 | OOD Val Macro F1: 0.4328 | Time: 28.27 min
# Seed 2024 | OOD Epoch 6/8: 100%|█| 5205/5205 [26:09<00:00,  3.32it/s, loss=0.015
# Seed 2024 | Epoch 06 | Train Loss: 0.1538 | OOD Val Loss: 1.0376 | OOD Val Macro F1: 0.4026 | Time: 28.28 min
# Seed 2024 | OOD Epoch 7/8: 100%|█| 5205/5205 [26:11<00:00,  3.31it/s, loss=0.181
# Seed 2024 | Epoch 07 | Train Loss: 0.1133 | OOD Val Loss: 1.0421 | OOD Val Macro F1: 0.4432 | Time: 28.32 min
# Seed 2024 | OOD Epoch 8/8: 100%|█| 5205/5205 [26:12<00:00,  3.31it/s, loss=0.375
# Seed 2024 | Epoch 08 | Train Loss: 0.0878 | OOD Val Loss: 1.2339 | OOD Val Macro F1: 0.4461 | Time: 28.35 min
#
# ================================================================================
# Starting OOD baseline seed 2025
# ================================================================================
#
# Using unweighted cross entropy.
#
# Starting OOD training...
# Seed 2025 | OOD Epoch 1/8: 100%|█| 5205/5205 [26:20<00:00,  3.29it/s, loss=0.748
# Seed 2025 | Epoch 01 | Train Loss: 0.4786 | OOD Val Loss: 0.9776 | OOD Val Macro F1: 0.4198 | Time: 28.55 min
# Seed 2025 | OOD Epoch 2/8: 100%|█| 5205/5205 [26:22<00:00,  3.29it/s, loss=0.095
# Seed 2025 | Epoch 02 | Train Loss: 0.3824 | OOD Val Loss: 0.7866 | OOD Val Macro F1: 0.4468 | Time: 28.53 min
# Seed 2025 | OOD Epoch 3/8: 100%|█| 5205/5205 [26:37<00:00,  3.26it/s, loss=0.097
# Seed 2025 | Epoch 03 | Train Loss: 0.3341 | OOD Val Loss: 1.0123 | OOD Val Macro F1: 0.4208 | Time: 28.79 min
# Seed 2025 | OOD Epoch 4/8: 100%|█| 5205/5205 [28:18<00:00,  3.06it/s, loss=0.305
# Seed 2025 | Epoch 04 | Train Loss: 0.2838 | OOD Val Loss: 0.8000 | OOD Val Macro F1: 0.4687 | Time: 30.59 min
# Seed 2025 | OOD Epoch 5/8: 100%|█| 5205/5205 [1:25:07<00:00,  1.02it/s, loss=0.2
# Seed 2025 | Epoch 05 | Train Loss: 0.2187 | OOD Val Loss: 0.9433 | OOD Val Macro F1: 0.4471 | Time: 87.14 min
# Seed 2025 | OOD Epoch 6/8: 100%|█| 5205/5205 [27:40<00:00,  3.13it/s, loss=0.481
# Seed 2025 | Epoch 06 | Train Loss: 0.1551 | OOD Val Loss: 1.0090 | OOD Val Macro F1: 0.4296 | Time: 30.02 min
# Seed 2025 | OOD Epoch 7/8: 100%|█| 5205/5205 [30:24<00:00,  2.85it/s, loss=0.257
# Seed 2025 | Epoch 07 | Train Loss: 0.1109 | OOD Val Loss: 1.2205 | OOD Val Macro F1: 0.4231 | Time: 32.88 min
# Seed 2025 | OOD Epoch 8/8: 100%|█| 5205/5205 [1:13:12<00:00,  1.18it/s, loss=0.0
# Seed 2025 | Epoch 08 | Train Loss: 0.0881 | OOD Val Loss: 1.1438 | OOD Val Macro F1: 0.4176 | Time: 75.50 min
#
# ================================================================================
# 1SE model selection
# ================================================================================
# {
#   "best_epoch_by_mean_ood_validation_f1": 3,
#   "best_mean_ood_validation_macro_f1": 0.4312150102165657,
#   "std_at_best_epoch": 0.024140858797554562,
#   "se_at_best_epoch": 0.010796120261311166,
#   "one_se_threshold": 0.42041888995525456,
#   "selected_epoch_1se_rule": 2
# }
#
# --------------------------------------------------------------------------------
# Evaluating OOD baseline seed 42, selected epoch 2
# --------------------------------------------------------------------------------
#
# Seed 42 | Final OOD VAL Macro F1: 0.4535
#               precision    recall  f1-score   support
#
#    no-damage     0.9382    0.7150    0.8115     37859
# minor-damage     0.0210    0.1008    0.0347       625
# major-damage     0.1124    0.4903    0.1829      2260
#    destroyed     0.8592    0.7223    0.7848      6089
#
#     accuracy                         0.6969     46833
#    macro avg     0.4827    0.5071    0.4535     46833
# weighted avg     0.8758    0.6969    0.7673     46833
#
#
# Seed 42 | Final OOD HOLD Macro F1: 0.3664
#               precision    recall  f1-score   support
#
#    no-damage     0.8252    0.7751    0.7993     38388
# minor-damage     0.2647    0.4085    0.3213      8428
# major-damage     0.1455    0.1443    0.1449      3029
#    destroyed     0.3671    0.1374    0.2000      3558
#
#     accuracy                         0.6390     53403
#    macro avg     0.4006    0.3663    0.3664     53403
# weighted avg     0.6676    0.6390    0.6468     53403
#
#
# --------------------------------------------------------------------------------
# Evaluating OOD baseline seed 123, selected epoch 2
# --------------------------------------------------------------------------------
#
# Seed 123 | Final OOD VAL Macro F1: 0.3565
#               precision    recall  f1-score   support
#
#    no-damage     0.9081    0.6348    0.7472     37859
# minor-damage     0.0216    0.1616    0.0381       625
# major-damage     0.0697    0.3947    0.1185      2260
#    destroyed     0.8111    0.3850    0.5221      6089
#
#     accuracy                         0.5844     46833
#    macro avg     0.4526    0.3940    0.3565     46833
# weighted avg     0.8432    0.5844    0.6782     46833
#
#
# Seed 123 | Final OOD HOLD Macro F1: 0.3357
#               precision    recall  f1-score   support
#
#    no-damage     0.7964    0.8015    0.7989     38388
# minor-damage     0.2438    0.2986    0.2685      8428
# major-damage     0.1146    0.1350    0.1240      3029
#    destroyed     0.3831    0.0944    0.1515      3558
#
#     accuracy                         0.6372     53403
#    macro avg     0.3845    0.3324    0.3357     53403
# weighted avg     0.6430    0.6372    0.6338     53403
#
#
# --------------------------------------------------------------------------------
# Evaluating OOD baseline seed 999, selected epoch 2
# --------------------------------------------------------------------------------
#
# Seed 999 | Final OOD VAL Macro F1: 0.4232
#               precision    recall  f1-score   support
#
#    no-damage     0.9261    0.6480    0.7625     37859
# minor-damage     0.0270    0.1872    0.0473       625
# major-damage     0.1061    0.5518    0.1779      2260
#    destroyed     0.8569    0.5989    0.7051      6089
#
#     accuracy                         0.6309     46833
#    macro avg     0.4790    0.4965    0.4232     46833
# weighted avg     0.8655    0.6309    0.7173     46833
#
#
# Seed 999 | Final OOD HOLD Macro F1: 0.3683
#               precision    recall  f1-score   support
#
#    no-damage     0.8065    0.8002    0.8033     38388
# minor-damage     0.2460    0.2890    0.2658      8428
# major-damage     0.1306    0.1499    0.1396      3029
#    destroyed     0.3757    0.2043    0.2647      3558
#
#     accuracy                         0.6429     53403
#    macro avg     0.3897    0.3609    0.3683     53403
# weighted avg     0.6510    0.6429    0.6449     53403
#
#
# --------------------------------------------------------------------------------
# Evaluating OOD baseline seed 2024, selected epoch 2
# --------------------------------------------------------------------------------
#
# Seed 2024 | Final OOD VAL Macro F1: 0.4296
#               precision    recall  f1-score   support
#
#    no-damage     0.9295    0.6123    0.7383     37859
# minor-damage     0.0227    0.1360    0.0390       625
# major-damage     0.0936    0.5372    0.1594      2260
#    destroyed     0.8497    0.7239    0.7818      6089
#
#     accuracy                         0.6168     46833
#    macro avg     0.4739    0.5023    0.4296     46833
# weighted avg     0.8667    0.6168    0.7066     46833
#
#
# Seed 2024 | Final OOD HOLD Macro F1: 0.3492
#               precision    recall  f1-score   support
#
#    no-damage     0.8013    0.7912    0.7962     38388
# minor-damage     0.2466    0.3289    0.2818      8428
# major-damage     0.0836    0.0723    0.0775      3029
#    destroyed     0.3829    0.1759    0.2411      3558
#
#     accuracy                         0.6365     53403
#    macro avg     0.3786    0.3421    0.3492     53403
# weighted avg     0.6452    0.6365    0.6373     53403
#
#
# --------------------------------------------------------------------------------
# Evaluating OOD baseline seed 2025, selected epoch 2
# --------------------------------------------------------------------------------
#
# Seed 2025 | Final OOD VAL Macro F1: 0.4468
#               precision    recall  f1-score   support
#
#    no-damage     0.9275    0.7345    0.8198     37859
# minor-damage     0.0199    0.0784    0.0317       625
# major-damage     0.0834    0.3341    0.1335      2260
#    destroyed     0.8587    0.7523    0.8020      6089
#
#     accuracy                         0.7088     46833
#    macro avg     0.4724    0.4748    0.4468     46833
# weighted avg     0.8657    0.7088    0.7739     46833
#
#
# Seed 2025 | Final OOD HOLD Macro F1: 0.3561
#               precision    recall  f1-score   support
#
#    no-damage     0.7920    0.8452    0.8177     38388
# minor-damage     0.2707    0.2559    0.2631      8428
# major-damage     0.1009    0.0842    0.0918      3029
#    destroyed     0.3571    0.1945    0.2518      3558
#
#     accuracy                         0.6657     53403
#    macro avg     0.3802    0.3450    0.3561     53403
# weighted avg     0.6415    0.6657    0.6513     53403
#
#
# ================================================================================
# Final OOD mean, std, and SE across seeds
# ================================================================================
#                    metric      mean       std  ...       min       max  num_seeds
# 0        ood_val_macro_f1  0.421899  0.038591  ...  0.356470  0.453473          5
# 1       ood_hold_macro_f1  0.355143  0.013360  ...  0.335720  0.368341          5
# 2            ood_val_loss  0.908361  0.114228  ...  0.786629  1.048500          5
# 3           ood_hold_loss  1.006822  0.029133  ...  0.981290  1.054577          5
# 4    ood_val_f1_no_damage  0.775863  0.037474  ...  0.738252  0.819829          5
# 5        ood_val_f1_minor  0.038138  0.005852  ...  0.031705  0.047254          5
# 6        ood_val_f1_major  0.154446  0.027919  ...  0.118467  0.182884          5
# 7    ood_val_f1_destroyed  0.719149  0.116316  ...  0.522107  0.801996          5
# 8   ood_hold_f1_no_damage  0.803107  0.008550  ...  0.796246  0.817722          5
# 9       ood_hold_f1_minor  0.280086  0.024114  ...  0.263097  0.321250          5
# 10      ood_hold_f1_major  0.115552  0.029656  ...  0.077536  0.144870          5
# 11  ood_hold_f1_destroyed  0.221827  0.046174  ...  0.151522  0.264701          5
#
# [12 rows x 7 columns]
#
# Worst OOD hold environment by mean macro F1:
# {'split': 'ood_hold', 'environment': 'socal-fire', 'macro_f1_mean': 0.2862867954742608, 'macro_f1_std': 0.012825478486086532, 'macro_f1_min': 0.2640743555819533, 'macro_f1_max': 0.2972668336380477, 'num_seeds': 5, 'macro_f1_se': 0.005735728347770115}
#
# Saved all OOD baseline outputs successfully.
# /Users/paolo/Desktop/OOD_training_outputs/unweighted_baseline_resnet50_5seeds_1se
